# %%
import scipy as sp

# %%
list_numbers=[23,24,67,89]

# %%
import numpy as np
from scipy import stats

# %%
stats.zscore(list_numbers)
# Out:
# array([-0.97916192, -0.94387681,  0.57338311,  1.34965562])

# %%
import pandas as pd

# %%
df=pd.read_csv("Salary_Data.csv")
df
# Out:
#     YearsExperience  Salary  Unnamed: 2  Unnamed: 3  Unnamed: 4 Unnamed: 5  \
# 0               1.1   39343         NaN         NaN         NaN        NaN
# 1               1.3   46205         NaN         NaN         NaN       corr
# 2               1.5   37731         NaN         NaN         NaN        NaN
# 3               2.0   43525         NaN         NaN         NaN        NaN
# 4               2.2   39891         NaN         NaN         NaN        NaN
# 5               2.9   56642         NaN         NaN         NaN        NaN
# 6               3.0   60150         NaN         NaN         NaN        NaN
# 7               3.2   54445         NaN         NaN         NaN        NaN
# 8               3.2   64445         NaN         NaN         NaN        NaN
# 9               3.7   57189         NaN         NaN         NaN        NaN
# 10              3.9   63218         NaN         NaN         NaN        NaN
# ...

# %%
stats.zscore(df['Salary'])
# Out:
# array([-1.36011263, -1.10552744, -1.419919  , -1.20495739, -1.33978143,
#        -0.71830716, -0.58815781, -0.79981746, -0.42881019, -0.69801306,
#        -0.47433279, -0.74976858, -0.70662043, -0.70201994, -0.55250402,
#        -0.29921736, -0.37004264,  0.26285865,  0.19885989,  0.66547573,
#         0.58377993,  0.82623317,  0.93861127,  1.40274136,  1.24020308,
#         1.09740238,  1.51986835,  1.3590738 ,  1.72102849,  1.70177321])
