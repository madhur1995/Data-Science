# %%
import pandas as pd
import seaborn as sns
from numpy import median, mean

# %%
olympics_df = pd.read_csv('https://raw.githubusercontent.com/TrainingByPackt/Interactive-Data-Visualization-with-Python/master/datasets/athlete_events.csv')

# %%
olympics_df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
olympics_df.shape
# Out:
# (271116, 15)

# %%
olympics_df.size
# Out:
# 4066740

# %%
olympics_df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
olympics_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
olympics_df.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
sns.countplot(x="Medal", data=olympics_df)

# %%
olympics_df["Medal"].value_counts()
# Out:
# Gold      13372
# Bronze    13295
# Silver    13116
# Name: Medal, dtype: int64

# %%
olympics_df["Sex"].value_counts()
# Out:
# M    196594
# F     74522
# Name: Sex, dtype: int64

# %%
sns.countplot(x="Sex", data=olympics_df)

# %%
sns.countplot(x="Season", data=olympics_df)

# %%
sns.barplot(x="Medal", y="Age", data=olympics_df)

# %%
import matplotlib as plt

# %%
plt.bar(olympics_df['Medal'],olympics_df['Age'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-2f3e4a96cd52> in <module>
# ----> 1 plt.bar(olympics_df['Medal'],olympics_df['Age'])
#
# AttributeError: module 'matplotlib' has no attribute 'bar'

# %% [raw]
# https://www.geeksforgeeks.org/seaborn-barplot-method-in-python/

# %% [raw]
# A barplot is basically used to aggregate the categorical data according to some methods and by default it’s the mean

# %%
sns.barplot(x="Medal", y="Age", data=olympics_df, hue="Sex")

# %%
sns.barplot(x="Medal", y="Age", data=olympics_df, hue="Season")

# %% [raw]
# if contineous variable ,result below

# %%
sns.barplot(x="Medal", y="Age", data=olympics_df, hue="Height")

# %% [raw]
# https://www.geeksforgeeks.org/python-seaborn-jointplot-method/

# %%
sns.jointplot(x="Height", y="Weight", data=olympics_df)

# %% [raw]
# JOINT PLOT IS COMBINATION OF SCATTER PLOT & HISTOGRAM(SEABORN)

# %%
sns.jointplot(x="Weight", y="Season", data=olympics_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-4e5f465693d4> in <module>
# ----> 1 sns.jointplot(x="Weight", y="Season", data=olympics_df)
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, stat_func, color, height, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2299         marginal_kws.setdefault("kde", False)
#    2300         marginal_kws.setdefault("color", color)
# -> 2301         grid.plot_marginals(distplot, **marginal_kws)
#    2302
#    2303     elif kind.startswith("hex"):
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in plot_marginals(self, func, **kwargs)
#    1812         kwargs["vertical"] = True
#    1813         plt.sca(self.ax_marg_y)
# -> 1814         func(self.y, **kwargs)
#    1815
#    1816         return self
#
# ...

# %%
sns.jointplot(x="Season", y="Weight", data=olympics_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-d9c8e3d48f63> in <module>
# ----> 1 sns.jointplot(x="Season", y="Weight", data=olympics_df)
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, stat_func, color, height, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2299         marginal_kws.setdefault("kde", False)
#    2300         marginal_kws.setdefault("color", color)
# -> 2301         grid.plot_marginals(distplot, **marginal_kws)
#    2302
#    2303     elif kind.startswith("hex"):
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in plot_marginals(self, func, **kwargs)
#    1808         kwargs["vertical"] = False
#    1809         plt.sca(self.ax_marg_x)
# -> 1810         func(self.x, **kwargs)
#    1811
#    1812         kwargs["vertical"] = True
#
# ...

# %%
sns.distplot(olympics_df["Age"],kde=False)

# %% [raw]
# https://www.geeksforgeeks.org/seaborn-distribution-plots/

# %% [markdown]
# https://github.com/TrainingByPackt/Interactive-Data-Visualization-with-Python/blob/master/Lesson01/Activity01.ipynb

# %% [markdown]
# https://www.geeksforgeeks.org/seaborn-distribution-plots/

# %% [raw]
# Dist plot is like histogram & ditributing.kernal density feature help data is skewed or distributed

# %%
olympics_df["Age"].skew()
# Out:
# 1.747122537787137

# %%
olympics_df["Age"].kurt()
# Out:
# 6.27064244661449

# %%
sns.pairplot(olympics_df)

# %%
sns.pairplot(olympics_df,hue="Season")

# %%
sns.pairplot(olympics_df,hue="Sex")

# %% [markdown]
# # Rugplot

# %%
sns.rugplot(olympics_df['Age'])

# %% [markdown]
# https://github.com/TrainingByPackt/Interactive-Data-Visualization-with-Python/blob/master/Lesson01/Activity01.ipynb

# %% [markdown]
# # Catplot

# %%
g = sns.catplot('Sport', data=olympics_df, kind="count", aspect=1.5)

# %% [markdown]
# https://github.com/TrainingByPackt/Interactive-Data-Visualization-with-Python/blob/master/datasets/diamonds.csv

# %% [raw]
# PERFORM UNIVARIANT & BIVARIANT

# %%
olympics_winners = olympics_df.dropna(subset=['Medal'])
olympics_winners.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e658e6f96444> in <module>
# ----> 1 olympics_winners = olympics_df.dropna(subset=['Medal'])
#       2 olympics_winners.head()
#
# NameError: name 'olympics_df' is not defined

# %%
olympics_winners_2016 = olympics_winners[(olympics_winners.Year == 2016)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-87425f2342e7> in <module>
# ----> 1 olympics_winners_2016 = olympics_winners[(olympics_winners.Year == 2016)]
#
# NameError: name 'olympics_winners' is not defined

# %%
olympics_winners_2016['Sport'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-4f8eaa4e3301> in <module>
# ----> 1 olympics_winners_2016['Sport'].value_counts()
#
# NameError: name 'olympics_winners_2016' is not defined

# %%
sns.countplot(x="Sport", data=olympics_winners_2016)

# %%
# list the top 5 sports
top_sports = ['Athletics', 'Swimming', 'Rowing', 'Football', 'Hockey']

# subset the dataframe to include data from the top sports
olympics_top_sports_winners_2016 = olympics_winners_2016[(olympics_winners_2016.Sport.isin(top_sports))]
olympics_top_sports_winners_2016.head()

# %%
sns.countplot(x="Sport", data=olympics_top_sports_winners_2016)

# %%
g = sns.catplot('Sport', data=olympics_top_sports_winners_2016, kind="count", aspect=1.5)

# %% [markdown]
# https://seaborn.pydata.org/generated/seaborn.catplot.html

# %%
g = sns.catplot('Age', data=olympics_top_sports_winners_2016, kind="box")

# %%
g = sns.catplot('Height', data=olympics_top_sports_winners_2016, kind="violin")

# %%
g = sns.catplot(x = 'Medal', y = 'Age', data=olympics_top_sports_winners_2016, kind="bar")
