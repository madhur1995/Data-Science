# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv("movies_data.csv")
df
# Out:
#     Rank                                          Title Worldwide gross  Year
# 0      1                                         Avatar  $2,787,965,087  2009
# 1      2                                        Titanic  $2,186,772,302  1997
# 2      3                   Star Wars: The Force Awakens  $2,068,223,624  2015
# 3      4                                 Jurassic World  $1,671,713,208  2015
# 4      5                                   The Avengers  $1,518,812,988  2012
# 5      6                                      Furious 7  $1,516,045,911  2015
# 6      7                        Avengers: Age of Ultron  $1,405,403,694  2015
# 7      8  Harry Potter and the Deathly Hallows – Part 2  $1,341,511,219  2011
# 8      9                                         Frozen  $1,287,000,000  2013
# 9     10                           Beauty and the Beast  $1,257,024,611  2017
# 10    11                        The Fate of the Furious  $1,238,290,870  2017
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Rank             50 non-null     int64
#  1   Title            50 non-null     object
#  2   Worldwide gross  50 non-null     object
#  3   Year             50 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 1.7+ KB

# %%
df.describe()
# Out:
#            Rank         Year
# count  50.00000    50.000000
# mean   25.50000  2009.760000
# std    14.57738     6.069529
# min     1.00000  1993.000000
# 25%    13.25000  2007.000000
# 50%    25.50000  2011.500000
# 75%    37.75000  2015.000000
# max    50.00000  2017.000000

# %%
df.replace(to_replace ="$",value ="0")
# Out:
#     Rank                                          Title Worldwide gross  Year
# 0      1                                         Avatar  $2,787,965,087  2009
# 1      2                                        Titanic  $2,186,772,302  1997
# 2      3                   Star Wars: The Force Awakens  $2,068,223,624  2015
# 3      4                                 Jurassic World  $1,671,713,208  2015
# 4      5                                   The Avengers  $1,518,812,988  2012
# 5      6                                      Furious 7  $1,516,045,911  2015
# 6      7                        Avengers: Age of Ultron  $1,405,403,694  2015
# 7      8  Harry Potter and the Deathly Hallows – Part 2  $1,341,511,219  2011
# 8      9                                         Frozen  $1,287,000,000  2013
# 9     10                           Beauty and the Beast  $1,257,024,611  2017
# 10    11                        The Fate of the Furious  $1,238,290,870  2017
# ...

# %%
df['Worldwide gross']= df['Worldwide gross'].replace('[\$,]', '', regex=True).astype(int)

# %%
df
# Out:
#     Rank                                          Title  Worldwide gross  Year
# 0      1                                         Avatar       2787965087  2009
# 1      2                                        Titanic       2186772302  1997
# 2      3                   Star Wars: The Force Awakens       2068223624  2015
# 3      4                                 Jurassic World       1671713208  2015
# 4      5                                   The Avengers       1518812988  2012
# 5      6                                      Furious 7       1516045911  2015
# 6      7                        Avengers: Age of Ultron       1405403694  2015
# 7      8  Harry Potter and the Deathly Hallows – Part 2       1341511219  2011
# 8      9                                         Frozen       1287000000  2013
# 9     10                           Beauty and the Beast       1257024611  2017
# 10    11                        The Fate of the Furious       1238290870  2017
# ...

# %%
df.describe()
# Out:
#            Rank  Worldwide gross         Year
# count  50.00000     5.000000e+01    50.000000
# mean   25.50000     1.146191e+09  2009.760000
# std    14.57738     3.628645e+08     6.069529
# min     1.00000     8.754579e+08  1993.000000
# 25%    13.25000     9.566066e+08  2007.000000
# 50%    25.50000     1.027808e+09  2011.500000
# 75%    37.75000     1.157875e+09  2015.000000
# max    50.00000     2.787965e+09  2017.000000

# %%
df['Worldwide gross']=pd.to_numeric(df['Worldwide gross'])

# %%
df.skew()
# Out:
# Rank               0.000000
# Worldwide gross    2.835699
# Year              -1.061195
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Rank             50 non-null     int64
#  1   Title            50 non-null     object
#  2   Worldwide gross  50 non-null     int64
#  3   Year             50 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 1.7+ KB

# %%
df.kurt()
# Out:
# Rank              -1.200000
# Worldwide gross    9.228990
# Year               0.549364
# dtype: float64

# %%
df['Worldwide gross'].hist()
# Out:
# <AxesSubplot:>

# %%
plt.hist(df['Worldwide gross'])
plt.show()

# %%
plt.boxplot(df['Worldwide gross'])
plt.show()

# %%
print(df['Worldwide gross'].quantile(0.50))
print(df['Worldwide gross'].quantile(0.90))
# Out:
# 1027807783.0
# 1516322618.7

# %%
df['Worldwide gross']=np.where(df['Worldwide gross'] >=1516322618.7,1027807783.0,df['Worldwide gross'])

# %%
plt.boxplot(df['Worldwide gross'])
plt.show()

# %%
print(df['Worldwide gross'].quantile(0.05))
print(df['Worldwide gross'].quantile(0.95))
# Out:
# 879742372.75
# 1889793936.7999988

# %%
index=df[(df['Worldwide gross'] <=879742372.75) | (df['Worldwide gross']>= 1316981170.4499998)].index
df.drop(index,inplace=True)

# %%
plt.boxplot(df['Worldwide gross'])
plt.show()

# %%
plt.hist(df['Worldwide gross'])
plt.show()

# %%
df['Worldwide gross'].skew()
# Out:
# 0.7502256796038738

# %%
df['Worldwide gross'].kurt()
# Out:
# -0.055014662685680005
